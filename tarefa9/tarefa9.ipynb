# %%
import cv2
import numpy as np

# %%
# Load the stereo images
img = cv2.imread('images/left2.jpg')
img2 = cv2.imread('images/right2.jpg')


# convert stereo images to grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
# get the size of the images
# l -> lines
# c -> columns
# v -> channel (RGB)
l,c,v = img.shape

# initialize arrays
minSAD = np.ones((l,c)) * 999999
sad = np.ones((l,c))
sad1 = np.ones((l,c))
winsad = np.ones((l,c))
disp = np.zeros((l,c))
distance = np.zeros((l,c))

max_shift = 60

# set size of the SAD window
w_l = 7
w_c = 7

for shift in range(max_shift):
    print("New Shift: %d"%(shift))
    for u in range(0,l):
        for v in range(0,c):
            # calculate SAD
            #if(v+shift <= l):
            if (int(w_c/2) <= v):
                 d = v - int(shift/2)
            else: 
                if (int(shift/4) <= v) :
                    d = v - int(shift/4)
                else:
                    d = v
            if (d + shift < c):
                sad[u,v] = np.abs((int(gray[u,v]) - int(gray2[u,d+shift])))
                distance [u,v] = np.abs(v - d+shift)


    for u in range (0,l):
        for v in range (0,c):
            sum_sad = 0
            for d in range(w_l):
                for e in range(w_c):
                    if(u+d < l and v+e < c):
                        sum_sad +=  sad[u+d,v+e]

    #Save disparity
    if(sum_sad < minSAD[u,v]):
        minSAD[u,v] = winsad[u,v]
        disp[u,v] = distance[u,v]


print("Process Complete")
#write disparity map to image
cv2.imwrite('sad.png',disp)
print("Disparity Map Generated1")
img3 = cv2.imread('sad.png',0)
print("Disparity Map Generated2")
equ = cv2.equalizeHist(img3)
#equ=img3
#cv2.imshow('im3', img3)
print("Disparity Map Generated3")
cv2.imwrite('equ.png',equ)
# Out:
# New Shift: 0
# New Shift: 1
# New Shift: 2
# New Shift: 3
# New Shift: 4
# New Shift: 5
# New Shift: 6
# New Shift: 7
# New Shift: 8
# New Shift: 9
# New Shift: 10
# New Shift: 11
# New Shift: 12
# New Shift: 13
# New Shift: 14
# New Shift: 15
# New Shift: 16
# New Shift: 17
# New Shift: 18
# New Shift: 19
# New Shift: 20
# New Shift: 21
# New Shift: 22
# New Shift: 23
# New Shift: 24
# New Shift: 25
# New Shift: 26
# New Shift: 27
# New Shift: 28
# New Shift: 29
# New Shift: 30
# New Shift: 31
# New Shift: 32
# New Shift: 33
# New Shift: 34
# New Shift: 35
# New Shift: 36
# New Shift: 37
# New Shift: 38
# New Shift: 39
# New Shift: 40
# New Shift: 41
# New Shift: 42
# New Shift: 43
# New Shift: 44
# New Shift: 45
# New Shift: 46
# New Shift: 47
# New Shift: 48
# New Shift: 49
# New Shift: 50
# New Shift: 51
# New Shift: 52
# New Shift: 53
# New Shift: 54
# New Shift: 55
# New Shift: 56
# New Shift: 57
# New Shift: 58
# New Shift: 59
# Process Complete
# Disparity Map Generated1
# Disparity Map Generated2
# Disparity Map Generated3
# True

# %%
s = cv2.imread('equ.png')

cv2.imshow('asdas', s)
cv2.waitKey(0)
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7f6333a386cb> in <module>()
# ----> 1 x = cv2.normalize(disp, 255, 0, cv2.NORM_MINMAX, np.uint8)
#
# NameError: name 'disp' is not defined
